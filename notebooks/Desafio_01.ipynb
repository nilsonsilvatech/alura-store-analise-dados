# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# %who
# Out:
# loja	 loja2	 loja3	 loja4	 pd	 url	 url2	 url3	 url4

# %%
faturamento_loja1 = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

print("Faturamento Loja 1:", faturamento_loja1)
print("Faturamento Loja 2:", faturamento_loja2)
print("Faturamento Loja 3:", faturamento_loja3)
print("Faturamento Loja 4:", faturamento_loja4)
# Out:
# Faturamento Loja 1: 1534509.12
# Faturamento Loja 2: 1488459.06
# Faturamento Loja 3: 1464025.03
# Faturamento Loja 4: 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
loja.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
categoria_loja1 = loja.groupby('Categoria do Produto')['Produto'].count().sort_values(ascending=False)
categoria_loja1
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: Produto, dtype: int64

# %%
categoria_loja2 = loja2.groupby('Categoria do Produto')['Produto'].count().sort_values(ascending=False)
categoria_loja2
# Out:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: Produto, dtype: int64

# %%
categoria_loja3 = loja3.groupby('Categoria do Produto')['Produto'].count().sort_values(ascending=False)
categoria_loja3
# Out:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: Produto, dtype: int64

# %%
categoria_loja4 = loja4.groupby('Categoria do Produto')['Produto'].count().sort_values(ascending=False)
categoria_loja4
# Out:
# Categoria do Produto
# moveis                   480
# eletronicos              451
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# livros                   187
# instrumentos musicais    170
# Name: Produto, dtype: int64

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_loja1 = loja['Avaliação da compra'].mean()
media_loja1
round(media_loja1, 2)
# Out:
# np.float64(3.98)

# %%
media_loja2 = loja2['Avaliação da compra'].mean()
media_loja2
round(media_loja2, 2)
# Out:
# np.float64(4.04)

# %%
media_loja3 = loja3['Avaliação da compra'].mean()
media_loja3
round(media_loja3, 2)
# Out:
# np.float64(4.05)

# %%
media_loja4 = loja4['Avaliação da compra'].mean()
media_loja4
round(media_loja4, 2)
# Out:
# np.float64(4.0)

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_loja1 = loja['Produto'].value_counts()

mais_vendido_loja1 = produtos_loja1.idxmax()
menos_vendido_loja1 = produtos_loja1.idxmin()

print("Loja 1")
print("Mais vendido:", mais_vendido_loja1)
print("Menos vendido:", menos_vendido_loja1)
# Out:
# Loja 1
# Mais vendido: Micro-ondas
# Menos vendido: Headset

# %%
produtos_loja2 = loja2['Produto'].value_counts()

mais_vendido_loja2 = produtos_loja2.idxmax()
menos_vendido_loja2 = produtos_loja2.idxmin()

print("Loja 2")
print("Mais vendido:", mais_vendido_loja2)
print("Menos vendido:", menos_vendido_loja2)
# Out:
# Loja 2
# Mais vendido: Iniciando em programação
# Menos vendido: Jogo de tabuleiro

# %%
produtos_loja3 = loja3['Produto'].value_counts()

mais_vendido_loja3 = produtos_loja3.idxmax()
menos_vendido_loja3 = produtos_loja3.idxmin()

print("Loja 3")
print("Mais vendido:", mais_vendido_loja3)
print("Menos vendido:", menos_vendido_loja3)
# Out:
# Loja 3
# Mais vendido: Kit banquetas
# Menos vendido: Blocos de montar

# %%
produtos_loja4 = loja4['Produto'].value_counts()

mais_vendido_loja4 = produtos_loja4.idxmax()
menos_vendido_loja4 = produtos_loja4.idxmin()

print("Loja 4")
print("Mais vendido:", mais_vendido_loja4)
print("Menos vendido:", menos_vendido_loja4)
# Out:
# Loja 4
# Mais vendido: Cama box
# Menos vendido: Guitarra

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio_loja1 = loja['Frete'].mean()
round(frete_medio_loja1, 2)
# Out:
# np.float64(34.69)

# %%
frete_medio_loja2 = loja2['Frete'].mean()
round(frete_medio_loja2, 2)
# Out:
# np.float64(33.62)

# %%
frete_medio_loja3 = loja3['Frete'].mean()
round(frete_medio_loja3, 2)
# Out:
# np.float64(33.07)

# %%
frete_medio_loja4 = loja4['Frete'].mean()
round(frete_medio_loja4, 2)
# Out:
# np.float64(31.28)

# %%
loja['Frete'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Gráfico 1 - Faturamento por loja

# %%
import matplotlib.pyplot as plt

lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]

plt.figure()
plt.bar(lojas, faturamentos)
plt.title('Faturamento Total por Loja')
plt.xlabel('Lojas')
plt.ylabel('Faturamento')
plt.show()

# %% [markdown]
# #Gráfico 2 - Média de Avaliação

# %%
avaliacoes = [media_loja1, media_loja2, media_loja3, media_loja4]

plt.figure()
plt.bar(lojas, avaliacoes)
plt.title('Média de Avaliação por Loja')
plt.xlabel('Lojas')
plt.ylabel('Média de Avaliação')
plt.show()

# %% [markdown]
# #Gráfico 3 - Distribuição por categoria

# %%
plt.figure()
categoria_loja1.head(5).plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 5 Categorias - Loja 1')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Quantidade de registros por loja

# %%
print("Loja 1:", loja.shape[0])
print("Loja 2:", loja2.shape[0])
print("Loja 3:", loja3.shape[0])
print("Loja 4:", loja4.shape[0])
# Out:
# Loja 1: 2359
# Loja 2: 2359
# Loja 3: 2359
# Loja 4: 2358

# %% [markdown]
# # Preço médio por loja

# %%
print("Preço médio Loja 1:", round(loja['Preço'].mean(), 2))
print("Preço médio Loja 2:", round(loja2['Preço'].mean(), 2))
print("Preço médio Loja 3:", round(loja3['Preço'].mean(), 2))
print("Preço médio Loja 4:", round(loja4['Preço'].mean(), 2))
# Out:
# Preço médio Loja 1: 650.49
# Preço médio Loja 2: 630.97
# Preço médio Loja 3: 620.61
# Preço médio Loja 4: 587.15

# %% [markdown]
# # Quanto a loja depende do seu produto mais vendido

# %%
# Faturamento total
faturamento_total_1 = loja['Preço'].sum()

# Produto mais vendido (nome)
produto_mais_vendido_1 = loja['Produto'].value_counts().idxmax()

# Faturamento do produto mais vendido
faturamento_produto_1 = loja[loja['Produto'] == produto_mais_vendido_1]['Preço'].sum()

# Percentual
percentual_1 = (faturamento_produto_1 / faturamento_total_1) * 100

print("Produto carro-chefe Loja 1:", produto_mais_vendido_1)
print("Percentual de concentração:", round(percentual_1, 2), "%")
# Out:
# Produto carro-chefe Loja 1: Micro-ondas
# Percentual de concentração: 3.02 %

# %%
# Faturamento total
faturamento_total_2 = loja2['Preço'].sum()

# Produto mais vendido (nome)
produto_mais_vendido_2 = loja2['Produto'].value_counts().idxmax()

# Faturamento do produto mais vendido
faturamento_produto_2 = loja2[loja2['Produto'] == produto_mais_vendido_2]['Preço'].sum()

# Percentual
percentual_2 = (faturamento_produto_2 / faturamento_total_2) * 100

print("Produto carro-chefe Loja 2:", produto_mais_vendido_2)
print("Percentual de concentração:", round(percentual_2, 2), "%")
# Out:
# Produto carro-chefe Loja 2: Iniciando em programação
# Percentual de concentração: 0.28 %

# %%
# Faturamento total
faturamento_total_3 = loja3['Preço'].sum()

# Produto mais vendido (nome)
produto_mais_vendido_3 = loja3['Produto'].value_counts().idxmax()

# Faturamento do produto mais vendido
faturamento_produto_3 = loja3[loja3['Produto'] == produto_mais_vendido_3]['Preço'].sum()

# Percentual
percentual_3 = (faturamento_produto_3 / faturamento_total_3) * 100

print("Produto carro-chefe Loja 3:", produto_mais_vendido_3)
print("Percentual de concentração:", round(percentual_3, 2), "%")
# Out:
# Produto carro-chefe Loja 3: Kit banquetas
# Percentual de concentração: 1.52 %

# %%
# Faturamento total
faturamento_total_4 = loja4['Preço'].sum()

# Produto mais vendido (nome)
produto_mais_vendido_4 = loja4['Produto'].value_counts().idxmax()

# Faturamento do produto mais vendido
faturamento_produto_4 = loja4[loja4['Produto'] == produto_mais_vendido_4]['Preço'].sum()

# Percentual
percentual_4 = (faturamento_produto_4 / faturamento_total_4) * 100

print("Produto carro-chefe Loja 4:", produto_mais_vendido_4)
print("Percentual de concentração:", round(percentual_4, 2), "%")
# Out:
# Produto carro-chefe Loja 4: Cama box
# Percentual de concentração: 3.17 %

# %% [markdown]
# # Produto que mais fatura por loja

# %%
# Produto que mais gera faturamento
faturamento_por_produto_1 = loja.groupby('Produto')['Preço'].sum()

produto_top_receita_1 = faturamento_por_produto_1.idxmax()
valor_top_receita_1 = faturamento_por_produto_1.max()

faturamento_total_1 = loja['Preço'].sum()

percentual_receita_1 = (valor_top_receita_1 / faturamento_total_1) * 100

print("Produto que mais fatura Loja 1:", produto_top_receita_1)
print("Percentual sobre faturamento total:", round(percentual_receita_1, 2), "%")
# Out:
# Produto que mais fatura Loja 1: TV Led UHD 4K
# Percentual sobre faturamento total: 12.35 %

# %%
# Produto que mais gera faturamento
faturamento_por_produto_2 = loja2.groupby('Produto')['Preço'].sum()

produto_top_receita_2 = faturamento_por_produto_2.idxmax()
valor_top_receita_2 = faturamento_por_produto_2.max()

faturamento_total_2 = loja2['Preço'].sum()

percentual_receita_2 = (valor_top_receita_2 / faturamento_total_2) * 100

print("Produto que mais fatura Loja 2:", produto_top_receita_2)
print("Percentual sobre faturamento total:", round(percentual_receita_2, 2), "%")
# Out:
# Produto que mais fatura Loja 2: Celular Plus X42
# Percentual sobre faturamento total: 10.14 %

# %%
# Produto que mais gera faturamento
faturamento_por_produto_3 = loja3.groupby('Produto')['Preço'].sum()

produto_top_receita_3 = faturamento_por_produto_3.idxmax()
valor_top_receita_3 = faturamento_por_produto_3.max()

faturamento_total_3 = loja3['Preço'].sum()

percentual_receita_3 = (valor_top_receita_3 / faturamento_total_3) * 100

print("Produto que mais fatura Loja 3:", produto_top_receita_3)
print("Percentual sobre faturamento total:", round(percentual_receita_3, 2), "%")
# Out:
# Produto que mais fatura Loja 3: Geladeira
# Percentual sobre faturamento total: 9.1 %

# %%
# Produto que mais gera faturamento
faturamento_por_produto_4 = loja4.groupby('Produto')['Preço'].sum()

produto_top_receita_4 = faturamento_por_produto_4.idxmax()
valor_top_receita_4 = faturamento_por_produto_4.max()

faturamento_total_4 = loja4['Preço'].sum()

percentual_receita_4 = (valor_top_receita_4 / faturamento_total_4) * 100

print("Produto que mais fatura Loja 4:", produto_top_receita_4)
print("Percentual sobre faturamento total:", round(percentual_receita_4, 2), "%")
# Out:
# Produto que mais fatura Loja 4: Celular Plus X42
# Percentual sobre faturamento total: 9.31 %
